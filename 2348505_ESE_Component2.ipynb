# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushkaMazumdar2/Machine_Learning/blob/main/2348505_ESE_Component2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform
import psutil
import socket
import multiprocessing
import time
from datetime import datetime

# %%
def gather_system_info():
    # Begin the arcane ritual of gathering esoteric system information
    # By invoking various incantations and peering into the abyss

    # Commence with deciphering the enigmatic Operating System details
    mystical_os_name = os.name
    cryptic_platform = platform.system()
    cryptic_release_version = platform.release()

# %%
# Invoke the CPU spirits to reveal their mystic usage patterns
cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)

# Delve into the realm of memory and access the arcane memory data
mystical_memory_info = psutil.virtual_memory()
arcane_total_memory = mystical_memory_info.total
arcane_available_memory = mystical_memory_info.available
# Embark on a perilous journey to measure the essence of Disk Space
cryptic_disk_info = psutil.disk_usage('/')
mysterious_total_space = cryptic_disk_info.total
enigmatic_used_space = cryptic_disk_info.used
cryptic_free_space = cryptic_disk_info.free
# Reach out to the mystical Network spirits to uncover hostname and IP address
mystical_hostname = socket.gethostname()
arcane_ip_address = socket.gethostbyname(mystical_hostname)

# %%
# Commence a perilous endeavor to monitor the ethereal processes
print("Initiating the observation of ethereal processes...")
for spectral_process in psutil.process_iter(['pid', 'name']):
  spectral_pid = spectral_process.info['pid']
  spectral_name = spectral_process.info['name']
  print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")

if __name__ == '__main__':
    # Prepare the summoning circle for a separate, parallel dimension
    parallel_realm_gates = multiprocessing.Process(target=gather_system_info)

    # Open the gates and start the mysterious ritual in the background
    parallel_realm_gates.start()

    # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
    for i in range(1, 11):
        print(f"Number {i} (big size)")
        time.sleep(1)
# Out:
# Initiating the observation of ethereal processes...
# Spectral PID: 1, Spectral Name: docker-init
# Spectral PID: 7, Spectral Name: node
# Spectral PID: 20, Spectral Name: tail
# Spectral PID: 31, Spectral Name: oom_monitor.sh
# Spectral PID: 33, Spectral Name: run.sh
# Spectral PID: 35, Spectral Name: kernel_manager_proxy
# Spectral PID: 61, Spectral Name: python3
# Spectral PID: 62, Spectral Name: colab-fileshim.
# Spectral PID: 83, Spectral Name: jupyter-noteboo
# Spectral PID: 84, Spectral Name: dap_multiplexer
# Spectral PID: 557, Spectral Name: python3
# Spectral PID: 652, Spectral Name: python3
# Spectral PID: 689, Spectral Name: language_service
# Spectral PID: 701, Spectral Name: node
# Number 1 (big size)
# Number 2 (big size)
# Number 3 (big size)
# Number 4 (big size)
# Number 5 (big size)
# Number 6 (big size)
# Number 7 (big size)
# Number 8 (big size)
# Number 9 (big size)
# Number 10 (big size)

# %%
# Obtain the current system date and time
current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"System Date and Time: {current_datetime}")

# Display the final message
print("BackGround Record Starts..ALL THE BEST….")
# Out:
# System Date and Time: 2023-10-04 08:53:06
# BackGround Record Starts..ALL THE BEST….

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score ,f1_score,confusion_matrix,roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_csv("/content/Iris.csv")

# %% [markdown]
# **DATASET OVERVIEW**

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.shape
# Out:
# (150, 6)

# %%
sns.catplot(data= data,x='Species',kind='count')
plt.title("Distribution of the Species of Iris Dataset")
plt.show()

# %% [markdown]
# FEATURE IMPORTANCE AND SELECTION

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-87-6c71ac866e2e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
data = data.drop(columns=['Id'])

# %% [markdown]
# **VISUALIZATION**

# %%
plt.scatter(data['SepalLengthCm'],data['SepalWidthCm'])
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(data['PetalLengthCm'],data['PetalWidthCm'])
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(data['PetalLengthCm'],data['SepalWidthCm'])
plt.xlabel("PetalLengthCm")
plt.ylabel("SepalWidthCm")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(data['PetalLengthCm'],data['SepalLengthCm'])
plt.xlabel("PetalLengthCm")
plt.ylabel("SepalLengthCm")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(data['SepalLengthCm'],data['PetalWidthCm'])
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(data['SepalWidthCm'],data['PetalWidthCm'])
plt.xlabel("SepalWidthCm")
plt.ylabel("PetalWidthCm")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# SPLITTING THE DATASET INTO TRAINING AND TESTING

# %%
x = data.drop(columns=['Species'])
y = data['Species']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30)

# %% [markdown]
# LOGISTIC REGRESSION MODEL TRAINING

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_train.shape
# Out:
# (105, 4)

# %%
x_test.shape
# Out:
# (45, 4)

# %%
y_train.shape
# Out:
# (105,)

# %%
y_test.shape
# Out:
# (45,)

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# MODEL EVALUATION AND METRICS

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
print("The accuracy score is:",round(accuracy*100),"%")
# Out:
# The accuracy score is: 91 %

# %%
precision = precision_score(y_test,y_pred,average='micro')

# %%
print("The precision score is:",precision)
# Out:
# The precision score is: 0.9736842105263158

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
le = LabelEncoder()
y_pred = le.fit_transform(y_pred)
y_test = le.fit_transform(y_test)

# %% [markdown]
# ROC_CURVE cannot be plotted as it is only restricted to Binary classification task. It cannot be plotted against multiclass datasets as we can see from the error that multiclass format is not supported.

# %%
tpr,fpr,thresholds = roc_curve(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-644928b55004> in <cell line: 1>()
# ----> 1 tpr,fpr,thresholds = roc_curve(y_test,y_pred)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
#     993         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     994     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     747     y_type = type_of_target(y_true, input_name="y_true")
#     748     if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 749         raise ValueError("{0} format is not supported".format(y_type))
#     750
#     751     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics._plot.roc_curve import RocCurveDisplay
roc = roc_auc_score(tpr,fpr)
display = RocCurveDisplay(roc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-8ff5c608a9bc> in <cell line: 3>()
#       1 from sklearn.metrics import roc_curve
#       2 from sklearn.metrics._plot.roc_curve import RocCurveDisplay
# ----> 3 roc = roc_auc_score(tpr,fpr)
#       4 display = RocCurveDisplay(roc)
#
# NameError: name 'tpr' is not defined

# %%
roc_curve()

# %% [markdown]
# FEATURE SIGNIFICANCE

# %%
importance = model.coef_

# %%
importance
# Out:
# array([[-0.46740921,  0.84973391, -2.3013175 , -0.98670213],
#        [ 0.34240446, -0.35267828, -0.16230919, -0.82470898],
#        [ 0.12500475, -0.49705563,  2.46362669,  1.81141111]])

# %%
plt.plot(importance)
# Out:
# [<matplotlib.lines.Line2D at 0x799cdefc8cd0>,
#  <matplotlib.lines.Line2D at 0x799cdefcaad0>,
#  <matplotlib.lines.Line2D at 0x799cdefca9b0>,
#  <matplotlib.lines.Line2D at 0x799cdefcb700>]
